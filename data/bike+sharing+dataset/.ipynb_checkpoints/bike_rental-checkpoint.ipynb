# %%
import pandas as pd

# %%
path = 'Documents/GitHub/Week_4/Project/bike+sharing+dataset/hour.csv'

# %%
df = pd.read_csv('hour.csv')

# %%
df.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
# 5        6  2011-01-01       1   0     1   5        0        6           0
# 6        7  2011-01-01       1   0     1   6        0        6           0
# 7        8  2011-01-01       1   0     1   7        0        6           0
# 8        9  2011-01-01       1   0     1   8        0        6           0
# 9       10  2011-01-01       1   0     1   9        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81     0.0000       3          13   16
# ...

# %%
date_list = ['dteday','season','yr','mnth','holiday','weekday','workingday']
weather_list = ['weathersit','temp','atemp','hum','windspeed']
rental_list = ['hr','casual','registered', 'cnt']

# %%
df_date = df[date_list]
df_weather = df[weather_list]
df_rental = df[rental_list]

# %%
df_date.to_csv('bike_rental_date.csv')
# df_weather.to_csv('bike_rental_weather.csv')
# df_rental.to_csv('bike_rental_rental.csv')

# %%
df_date = df_date.drop_duplicates(subset=['dteday'])
